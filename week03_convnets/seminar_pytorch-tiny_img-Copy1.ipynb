# %% [markdown]
# # Deep learning for computer vision
#
#
# This notebook will teach you to build and train convolutional networks for image recognition. Brace yourselves.

# %% [markdown]
# # Tiny ImageNet dataset
# This week, we shall focus on the image recognition problem on cifar10 dataset
# * 100k images of shape 3x64x64
# * 200 different classes: snakes, spaiders, cats, trucks, grasshopper, gull, etc.

# %%
print (6)
# Out:
# 6

# %%
import numpy as np
from tiny_img import load_tiny_image, look_up_same_classes

X_train,y_train,X_val,y_val,X_test,y_test = load_tiny_image()

#class_names = np.array(['airplane','automobile ','bird ','cat ','deer ','dog ','frog ','horse ','ship ','truck'])

print (X_train.shape,y_train.shape)
# Out:
# ./tiny-imagenet-200/train/n02124075/images
# ./tiny-imagenet-200/train/n04067472/images
# ./tiny-imagenet-200/train/n04540053/images
# ./tiny-imagenet-200/train/n04099969/images
# ./tiny-imagenet-200/train/n07749582/images
# ./tiny-imagenet-200/train/n01641577/images
# ./tiny-imagenet-200/train/n02802426/images
# ./tiny-imagenet-200/train/n09246464/images
# ./tiny-imagenet-200/train/n07920052/images
# ./tiny-imagenet-200/train/n03970156/images
# ./tiny-imagenet-200/train/n03891332/images
# ./tiny-imagenet-200/train/n02106662/images
# ./tiny-imagenet-200/train/n03201208/images
# ./tiny-imagenet-200/train/n02279972/images
# ./tiny-imagenet-200/train/n02132136/images
# ./tiny-imagenet-200/train/n04146614/images
# ./tiny-imagenet-200/train/n07873807/images
# ./tiny-imagenet-200/train/n02364673/images
# ./tiny-imagenet-200/train/n04507155/images
# ./tiny-imagenet-200/train/n03854065/images
# ./tiny-imagenet-200/train/n03838899/images
# ./tiny-imagenet-200/train/n03733131/images
# ./tiny-imagenet-200/train/n01443537/images
# ./tiny-imagenet-200/train/n07875152/images
# ./tiny-imagenet-200/train/n03544143/images
# ./tiny-imagenet-200/train/n09428293/images
# ./tiny-imagenet-200/train/n03085013/images
# ./tiny-imagenet-200/train/n02437312/images
# ./tiny-imagenet-200/train/n07614500/images
# ./tiny-imagenet-200/train/n03804744/images
# ./tiny-imagenet-200/train/n04265275/images
# ./tiny-imagenet-200/train/n02963159/images
# ./tiny-imagenet-200/train/n02486410/images
# ./tiny-imagenet-200/train/n01944390/images
# ./tiny-imagenet-200/train/n09256479/images
# ./tiny-imagenet-200/train/n02058221/images
# ./tiny-imagenet-200/train/n04275548/images
# ./tiny-imagenet-200/train/n02321529/images
# ./tiny-imagenet-200/train/n02769748/images
# ./tiny-imagenet-200/train/n02099712/images
# ./tiny-imagenet-200/train/n07695742/images
# ./tiny-imagenet-200/train/n02056570/images
# ./tiny-imagenet-200/train/n02281406/images
# ./tiny-imagenet-200/train/n01774750/images
# ./tiny-imagenet-200/train/n02509815/images
# ./tiny-imagenet-200/train/n03983396/images
# ./tiny-imagenet-200/train/n07753592/images
# ./tiny-imagenet-200/train/n04254777/images
# ./tiny-imagenet-200/train/n02233338/images
# ./tiny-imagenet-200/train/n04008634/images
# ./tiny-imagenet-200/train/n02823428/images
# ./tiny-imagenet-200/train/n02236044/images
# ./tiny-imagenet-200/train/n03393912/images
# ./tiny-imagenet-200/train/n07583066/images
# ./tiny-imagenet-200/train/n04074963/images
# ./tiny-imagenet-200/train/n01629819/images
# ./tiny-imagenet-200/train/n09332890/images
# ./tiny-imagenet-200/train/n02481823/images
# ./tiny-imagenet-200/train/n03902125/images
# ./tiny-imagenet-200/train/n03404251/images
# ./tiny-imagenet-200/train/n09193705/images
# ./tiny-imagenet-200/train/n03637318/images
# ./tiny-imagenet-200/train/n04456115/images
# ./tiny-imagenet-200/train/n02666196/images
# ./tiny-imagenet-200/train/n03796401/images
# ./tiny-imagenet-200/train/n02795169/images
# ./tiny-imagenet-200/train/n02123045/images
# ./tiny-imagenet-200/train/n01855672/images
# ./tiny-imagenet-200/train/n01882714/images
# ./tiny-imagenet-200/train/n02917067/images
# ./tiny-imagenet-200/train/n02988304/images
# ./tiny-imagenet-200/train/n04398044/images
# ./tiny-imagenet-200/train/n02843684/images
# ./tiny-imagenet-200/train/n02423022/images
# ./tiny-imagenet-200/train/n02669723/images
# ./tiny-imagenet-200/train/n04465501/images
# ./tiny-imagenet-200/train/n02165456/images
# ./tiny-imagenet-200/train/n03770439/images
# ./tiny-imagenet-200/train/n02099601/images
# ./tiny-imagenet-200/train/n04486054/images
# ./tiny-imagenet-200/train/n02950826/images
# ./tiny-imagenet-200/train/n03814639/images
# ./tiny-imagenet-200/train/n04259630/images
# ./tiny-imagenet-200/train/n03424325/images
# ./tiny-imagenet-200/train/n02948072/images
# ./tiny-imagenet-200/train/n03179701/images
# ./tiny-imagenet-200/train/n03400231/images
# ./tiny-imagenet-200/train/n02206856/images
# ./tiny-imagenet-200/train/n03160309/images
# ./tiny-imagenet-200/train/n01984695/images
# ./tiny-imagenet-200/train/n03977966/images
# ./tiny-imagenet-200/train/n03584254/images
# ./tiny-imagenet-200/train/n04023962/images
# ./tiny-imagenet-200/train/n02814860/images
# ./tiny-imagenet-200/train/n01910747/images
# ./tiny-imagenet-200/train/n04596742/images
# ./tiny-imagenet-200/train/n03992509/images
# ./tiny-imagenet-200/train/n04133789/images
# ./tiny-imagenet-200/train/n03937543/images
# ./tiny-imagenet-200/train/n02927161/images
# ./tiny-imagenet-200/train/n01945685/images
# ./tiny-imagenet-200/train/n02395406/images
# ./tiny-imagenet-200/train/n02125311/images
# ./tiny-imagenet-200/train/n03126707/images
# ./tiny-imagenet-200/train/n04532106/images
# ./tiny-imagenet-200/train/n02268443/images
# ./tiny-imagenet-200/train/n02977058/images
# ./tiny-imagenet-200/train/n07734744/images
# ./tiny-imagenet-200/train/n03599486/images
# ./tiny-imagenet-200/train/n04562935/images
# ./tiny-imagenet-200/train/n03014705/images
# ./tiny-imagenet-200/train/n04251144/images
# ./tiny-imagenet-200/train/n04356056/images
# ./tiny-imagenet-200/train/n02190166/images
# ./tiny-imagenet-200/train/n03670208/images
# ./tiny-imagenet-200/train/n02002724/images
# ./tiny-imagenet-200/train/n02074367/images
# ./tiny-imagenet-200/train/n04285008/images
# ./tiny-imagenet-200/train/n04560804/images
# ./tiny-imagenet-200/train/n04366367/images
# ./tiny-imagenet-200/train/n02403003/images
# ./tiny-imagenet-200/train/n07615774/images
# ./tiny-imagenet-200/train/n04501370/images
# ./tiny-imagenet-200/train/n03026506/images
# ./tiny-imagenet-200/train/n02906734/images
# ./tiny-imagenet-200/train/n01770393/images
# ./tiny-imagenet-200/train/n04597913/images
# ./tiny-imagenet-200/train/n03930313/images
# ./tiny-imagenet-200/train/n04118538/images
# ./tiny-imagenet-200/train/n04179913/images
# ./tiny-imagenet-200/train/n04311004/images
# ./tiny-imagenet-200/train/n02123394/images
# ./tiny-imagenet-200/train/n04070727/images
# ./tiny-imagenet-200/train/n02793495/images
# ./tiny-imagenet-200/train/n02730930/images
# ./tiny-imagenet-200/train/n02094433/images
# ./tiny-imagenet-200/train/n04371430/images
# ./tiny-imagenet-200/train/n04328186/images
# ./tiny-imagenet-200/train/n03649909/images
# ./tiny-imagenet-200/train/n04417672/images
# ./tiny-imagenet-200/train/n03388043/images
# ./tiny-imagenet-200/train/n01774384/images
# ./tiny-imagenet-200/train/n02837789/images
# ./tiny-imagenet-200/train/n07579787/images
# ./tiny-imagenet-200/train/n04399382/images
# ./tiny-imagenet-200/train/n02791270/images
# ./tiny-imagenet-200/train/n03089624/images
# ./tiny-imagenet-200/train/n02814533/images
# ./tiny-imagenet-200/train/n04149813/images
# ./tiny-imagenet-200/train/n07747607/images
# ./tiny-imagenet-200/train/n03355925/images
# ./tiny-imagenet-200/train/n01983481/images
# ./tiny-imagenet-200/train/n04487081/images
# ./tiny-imagenet-200/train/n03250847/images
# ./tiny-imagenet-200/train/n03255030/images
# ./tiny-imagenet-200/train/n02892201/images
# ./tiny-imagenet-200/train/n02883205/images
# ./tiny-imagenet-200/train/n03100240/images
# ./tiny-imagenet-200/train/n02415577/images
# ./tiny-imagenet-200/train/n02480495/images
# ./tiny-imagenet-200/train/n01698640/images
# ./tiny-imagenet-200/train/n01784675/images
# ./tiny-imagenet-200/train/n04376876/images
# ./tiny-imagenet-200/train/n03444034/images
# ./tiny-imagenet-200/train/n01917289/images
# ./tiny-imagenet-200/train/n01950731/images
# ./tiny-imagenet-200/train/n03042490/images
# ./tiny-imagenet-200/train/n07711569/images
# ./tiny-imagenet-200/train/n04532670/images
# ./tiny-imagenet-200/train/n03763968/images
# ./tiny-imagenet-200/train/n07768694/images
# ./tiny-imagenet-200/train/n02999410/images
# ./tiny-imagenet-200/train/n03617480/images
# ./tiny-imagenet-200/train/n06596364/images
# ./tiny-imagenet-200/train/n01768244/images
# ./tiny-imagenet-200/train/n02410509/images
# ./tiny-imagenet-200/train/n03976657/images
# ./tiny-imagenet-200/train/n01742172/images
# ./tiny-imagenet-200/train/n03980874/images
# ./tiny-imagenet-200/train/n02808440/images
# ./tiny-imagenet-200/train/n02226429/images
# ./tiny-imagenet-200/train/n02231487/images
# ./tiny-imagenet-200/train/n02085620/images
# ./tiny-imagenet-200/train/n01644900/images
# ./tiny-imagenet-200/train/n02129165/images
# ./tiny-imagenet-200/train/n02699494/images
# ./tiny-imagenet-200/train/n03837869/images
# ./tiny-imagenet-200/train/n02815834/images
# ./tiny-imagenet-200/train/n07720875/images
# ./tiny-imagenet-200/train/n02788148/images
# ./tiny-imagenet-200/train/n02909870/images
# ./tiny-imagenet-200/train/n03706229/images
# ./tiny-imagenet-200/train/n07871810/images
# ./tiny-imagenet-200/train/n03447447/images
# ./tiny-imagenet-200/train/n02113799/images
# ./tiny-imagenet-200/train/n12267677/images
# ./tiny-imagenet-200/train/n03662601/images
# ./tiny-imagenet-200/train/n02841315/images
# ./tiny-imagenet-200/train/n07715103/images
# ./tiny-imagenet-200/train/n02504458/images
# 492
# 481
# 494
# 485
# 499
# 500
# 497
# 496
# 498
# 490
# 473
# 492
# 500
# 500
# 500
# 498
# 500
# 496
# 477
# 494
# 463
# 491
# 500
# 500
# 452
# 494
# 466
# 498
# 500
# 468
# 490
# 500
# 495
# 495
# 500
# 498
# 484
# 500
# 498
# 495
# 500
# 500
# 500
# 495
# 499
# 493
# 493
# 497
# 495
# 485
# 495
# 499
# 499
# 500
# 479
# 500
# 499
# 485
# 477
# 480
# 494
# 484
# 498
# 492
# 498
# 484
# 492
# 498
# 499
# 492
# 494
# 497
# 486
# 496
# 488
# 480
# 500
# 495
# 494
# 491
# 479
# 491
# 492
# 480
# 497
# 493
# 495
# 497
# 483
# 500
# 496
# 489
# 480
# 485
# 499
# 494
# 474
# 495
# 488
# 497
# 497
# 495
# 497
# 480
# 500
# 499
# 493
# 500
# 481
# 473
# 497
# 498
# 465
# 497
# 492
# 499
# 498
# 495
# 492
# 473
# 493
# 498
# 473
# 499
# 491
# 497
# 500
# 467
# 499
# 474
# 473
# 492
# 495
# 481
# 500
# 497
# 493
# 482
# 495
# 488
# 466
# 497
# 474
# 500
# 485
# 453
# 499
# 491
# 497
# 500
# 496
# 500
# 494
# 474
# 479
# 492
# 460
# 498
# 499
# 491
# 496
# 500
# 471
# 496
# 499
# 500
# 494
# 500
# 473
# 454
# 499
# 472
# 497
# 497
# 492
# 494
# 485
# 499
# 500
# 491
# 500
# 497
# 497
# 498
# 493
# 497
# 487
# 494
# 499
# 465
# 488
# 496
# 500
# 480
# 491
# 496
# 500
# 471
# 497
# 496
# shapes:  (68725, 3, 64, 64) (68725,) (20617, 3, 64, 64) (20617,) (8837, 3, 64, 64) (8837,)
# (68725, 3, 64, 64) (68725,)

# %% [markdown]
# ## Look at the picture of the same classes

# %%
import random
import matplotlib.pyplot as plt
# %matplotlib inline


def look_at_class(data, labels):
    class_n = random.randint(1,200)
    idxs = []
    print ("class ", class_n)
    for ind, label in enumerate(labels):
        if label == class_n:
            idxs.append(ind)
            
    data_for_show = data[idxs]
    for i in range(4):
        plt.subplot(2,2,i+1)
        plt.imshow(data_for_show[i].reshape(64,64,3))
    plt.show()
    

def look_up_same_classes(data, labels, number_of_classes = 4):
    for i in range(number_of_classes):
        look_at_class(data, labels)
    return 0

# %%
look_up_same_classes(X_train, y_train)
# Out:
# class  162
# class  147
# class  106
# class  24
# 0

# %% [markdown]
# # Building a network
#
# Simple neural networks with layers applied on top of one another can be implemented as `torch.nn.Sequential` - just add a list of pre-built modules and let it train.

# %%
import torch, torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

# a special module that converts [batch, channel, w, h] to [batch, units]
class Flatten(nn.Module):
    def forward(self, input):
        return input.view(input.size(0), -1)

# %% [markdown]
# Let's start with a dense network for our baseline:

# %%
model = nn.Sequential()

# reshape from "images" to flat vectors
model.add_module('flatten', Flatten())

# dense "head"
model.add_module('dense1', nn.Linear(3 * 64 * 64, 1064))
model.add_module('dense2', nn.Linear(1064, 512))
model.add_module('dropout0', nn.Dropout(0.05)) 
model.add_module('dense3', nn.Linear(512, 256))
model.add_module('dropout1', nn.Dropout(0.05))
model.add_module('dense4', nn.Linear(256, 64))
model.add_module('dropout2', nn.Dropout(0.05))
model.add_module('dense1_relu', nn.ReLU())
model.add_module('dense2_logits', nn.Linear(64, 200)) # logits for 200 classes

# %% [markdown]
# As in our basic tutorial, we train our model with negative log-likelihood aka crossentropy.

# %%
def compute_loss(X_batch, y_batch):
    X_batch = Variable(torch.FloatTensor(X_batch)).cuda()
    y_batch = Variable(torch.LongTensor(y_batch)).cuda()
    logits = model.cuda()(X_batch)
    return F.cross_entropy(logits, y_batch).mean()

# %%
X_train.shape
# Out:
# (68725, 3, 64, 64)

# %%
# example
compute_loss(X_train[:5], y_train[:5])
# Out:
# tensor(5.2448, device='cuda:0', grad_fn=<MeanBackward1>)

# %% [markdown]
# ### Training on minibatches
# * We got 40k images, that's way too many for a full-batch SGD. Let's train on minibatches instead
# * Below is a function that splits the training sample into minibatches

# %%
y_train[61]
# Out:
# 0

# %%
# An auxilary function that returns mini-batches for neural network training
def iterate_minibatches(X, y, batchsize):
    indices = np.random.permutation(np.arange(len(X)))
    for start in range(0, len(indices), batchsize):
        ix = indices[start: start + batchsize]
        yield X[ix], y[ix]

# %%
opt = torch.optim.SGD(model.parameters(), lr=0.01)

train_loss = []
val_accuracy = []
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8afbb61bc17f> in <module>()
# ----> 1 opt = torch.optim.SGD(model.parameters(), lr=0.01)
#       2
#       3 train_loss = []
#       4 val_accuracy = []
#
# NameError: name 'model' is not defined

# %%
import time
num_epochs = 100 # total amount of full passes over training data
batch_size = 50  # number of samples processed in one SGD iteration

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for X_batch, y_batch in iterate_minibatches(X_train, y_train, batch_size):
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.data.cpu().numpy())
        
    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in iterate_minibatches(X_val, y_val, batch_size):
        logits = model(Variable(torch.FloatTensor(X_batch)).cuda())
        y_pred = logits.cpu().max(1)[1].data.numpy()
        val_accuracy.append(np.mean(y_batch == y_pred))

    
    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(X_train) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(X_val) // batch_size :]) * 100))
# Out:
# Epoch 1 of 100 took 11.569s
#   training loss (in-iteration): 	5.296179
#   validation accuracy: 			1.05 %
# Epoch 2 of 100 took 11.052s
#   training loss (in-iteration): 	5.251684
#   validation accuracy: 			1.18 %
# Epoch 3 of 100 took 10.906s
#   training loss (in-iteration): 	5.133673
#   validation accuracy: 			1.96 %
# Epoch 4 of 100 took 11.024s
#   training loss (in-iteration): 	5.056474
#   validation accuracy: 			2.94 %
# Epoch 5 of 100 took 11.066s
#   training loss (in-iteration): 	4.976044
#   validation accuracy: 			3.48 %
# Epoch 6 of 100 took 11.089s
#   training loss (in-iteration): 	4.897729
#   validation accuracy: 			4.15 %
# Epoch 7 of 100 took 11.072s
#   training loss (in-iteration): 	4.846910
#   validation accuracy: 			4.53 %
# Epoch 8 of 100 took 10.880s
#   training loss (in-iteration): 	4.810978
#   validation accuracy: 			4.33 %
# Epoch 9 of 100 took 10.984s
#   training loss (in-iteration): 	4.779569
#   validation accuracy: 			5.18 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-da263c9e8810> in <module>()
#       7     start_time = time.time()
#       8     model.train(True) # enable dropout / batch_norm training behavior
# ----> 9     for X_batch, y_batch in iterate_minibatches(X_train, y_train, batch_size):
#      10         # train on batch
#      11         loss = compute_loss(X_batch, y_batch)
#
# <ipython-input-47-bf73adb52040> in iterate_minibatches(X, y, batchsize)
#       4     for start in range(0, len(indices), batchsize):
#       5         ix = indices[start: start + batchsize]
# ----> 6         yield X[ix], y[ix]
#
# KeyboardInterrupt:

# %%
import time
num_epochs = 100 # total amount of full passes over training data
batch_size = 50  # number of samples processed in one SGD iteration

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for X_batch, y_batch in iterate_minibatches(X_train, y_train, batch_size):
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.data.cpu().numpy())
        
    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in iterate_minibatches(X_val, y_val, batch_size):
        logits = model(Variable(torch.FloatTensor(X_batch)).cuda())
        y_pred = logits.cpu().max(1)[1].data.numpy()
        val_accuracy.append(np.mean(y_batch == y_pred))

    
    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(X_train) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(X_val) // batch_size :]) * 100))
# Out:
# Epoch 1 of 100 took 11.477s
#   training loss (in-iteration): 	5.083720
#   validation accuracy: 			2.61 %
# Epoch 2 of 100 took 11.435s
#   training loss (in-iteration): 	4.990971
#   validation accuracy: 			3.77 %
# Epoch 3 of 100 took 11.159s
#   training loss (in-iteration): 	4.904186
#   validation accuracy: 			4.47 %
# Epoch 4 of 100 took 11.168s
#   training loss (in-iteration): 	4.845609
#   validation accuracy: 			4.97 %
# Epoch 5 of 100 took 11.288s
#   training loss (in-iteration): 	4.803261
#   validation accuracy: 			5.33 %
# Epoch 6 of 100 took 11.034s
#   training loss (in-iteration): 	4.769786
#   validation accuracy: 			5.15 %
# Epoch 7 of 100 took 11.083s
#   training loss (in-iteration): 	4.741042
#   validation accuracy: 			5.65 %
# Epoch 8 of 100 took 11.184s
#   training loss (in-iteration): 	4.714520
#   validation accuracy: 			5.34 %
# Epoch 9 of 100 took 11.224s
#   training loss (in-iteration): 	4.691528
#   validation accuracy: 			5.98 %
# Epoch 10 of 100 took 11.147s
#   training loss (in-iteration): 	4.670466
#   validation accuracy: 			5.97 %
# Epoch 11 of 100 took 11.047s
#   training loss (in-iteration): 	4.648231
#   validation accuracy: 			6.31 %
# Epoch 12 of 100 took 11.006s
#   training loss (in-iteration): 	4.625829
#   validation accuracy: 			6.29 %
# Epoch 13 of 100 took 11.198s
#   training loss (in-iteration): 	4.606622
#   validation accuracy: 			6.86 %
# Epoch 14 of 100 took 11.222s
#   training loss (in-iteration): 	4.586405
#   validation accuracy: 			6.51 %
# Epoch 15 of 100 took 11.058s
#   training loss (in-iteration): 	4.566300
#   validation accuracy: 			7.13 %
# Epoch 16 of 100 took 11.036s
#   training loss (in-iteration): 	4.549792
#   validation accuracy: 			7.06 %
# Epoch 17 of 100 took 11.162s
#   training loss (in-iteration): 	4.533229
#   validation accuracy: 			7.58 %
# Epoch 18 of 100 took 11.203s
#   training loss (in-iteration): 	4.517184
#   validation accuracy: 			7.59 %
# Epoch 19 of 100 took 11.117s
#   training loss (in-iteration): 	4.504992
#   validation accuracy: 			7.45 %
# Epoch 20 of 100 took 11.011s
#   training loss (in-iteration): 	4.489184
#   validation accuracy: 			7.39 %
# Epoch 21 of 100 took 11.047s
#   training loss (in-iteration): 	4.474881
#   validation accuracy: 			7.69 %
# Epoch 22 of 100 took 11.193s
#   training loss (in-iteration): 	4.463737
#   validation accuracy: 			7.93 %
# Epoch 23 of 100 took 11.182s
#   training loss (in-iteration): 	4.453701
#   validation accuracy: 			7.66 %
# Epoch 24 of 100 took 11.088s
#   training loss (in-iteration): 	4.442380
#   validation accuracy: 			8.37 %
# Epoch 25 of 100 took 10.976s
#   training loss (in-iteration): 	4.426284
#   validation accuracy: 			7.88 %
# Epoch 26 of 100 took 11.013s
#   training loss (in-iteration): 	4.417593
#   validation accuracy: 			8.14 %
# Epoch 27 of 100 took 11.184s
#   training loss (in-iteration): 	4.408323
#   validation accuracy: 			7.85 %
# Epoch 28 of 100 took 11.249s
#   training loss (in-iteration): 	4.396608
#   validation accuracy: 			8.41 %
# Epoch 29 of 100 took 11.100s
#   training loss (in-iteration): 	4.384291
#   validation accuracy: 			8.28 %
# Epoch 30 of 100 took 10.984s
#   training loss (in-iteration): 	4.374659
#   validation accuracy: 			8.44 %
# Epoch 31 of 100 took 11.126s
#   training loss (in-iteration): 	4.364766
#   validation accuracy: 			7.74 %
# Epoch 32 of 100 took 11.204s
#   training loss (in-iteration): 	4.354668
#   validation accuracy: 			8.41 %
# Epoch 33 of 100 took 11.202s
#   training loss (in-iteration): 	4.343341
#   validation accuracy: 			8.71 %
# Epoch 34 of 100 took 11.035s
#   training loss (in-iteration): 	4.332900
#   validation accuracy: 			8.36 %
# Epoch 35 of 100 took 11.014s
#   training loss (in-iteration): 	4.320939
#   validation accuracy: 			8.54 %
# Epoch 36 of 100 took 11.075s
#   training loss (in-iteration): 	4.314013
#   validation accuracy: 			8.56 %
# Epoch 37 of 100 took 11.220s
#   training loss (in-iteration): 	4.304500
#   validation accuracy: 			8.57 %
# Epoch 38 of 100 took 11.194s
#   training loss (in-iteration): 	4.294363
#   validation accuracy: 			8.93 %
# Epoch 39 of 100 took 10.982s
#   training loss (in-iteration): 	4.284661
#   validation accuracy: 			8.66 %
# Epoch 40 of 100 took 11.034s
#   training loss (in-iteration): 	4.272855
#   validation accuracy: 			8.68 %
# Epoch 41 of 100 took 11.198s
#   training loss (in-iteration): 	4.268458
#   validation accuracy: 			7.88 %
# Epoch 42 of 100 took 11.202s
#   training loss (in-iteration): 	4.255331
#   validation accuracy: 			8.61 %
# Epoch 43 of 100 took 11.098s
#   training loss (in-iteration): 	4.245286
#   validation accuracy: 			7.66 %
# Epoch 44 of 100 took 10.979s
#   training loss (in-iteration): 	4.236741
#   validation accuracy: 			9.27 %
# Epoch 45 of 100 took 11.021s
#   training loss (in-iteration): 	4.226396
#   validation accuracy: 			8.11 %
# Epoch 46 of 100 took 11.128s
#   training loss (in-iteration): 	4.217675
#   validation accuracy: 			7.94 %
# Epoch 47 of 100 took 11.140s
#   training loss (in-iteration): 	4.211437
#   validation accuracy: 			8.26 %
# Epoch 48 of 100 took 11.115s
#   training loss (in-iteration): 	4.203225
#   validation accuracy: 			9.09 %
# Epoch 49 of 100 took 10.967s
#   training loss (in-iteration): 	4.194249
#   validation accuracy: 			8.74 %
# Epoch 50 of 100 took 11.135s
#   training loss (in-iteration): 	4.184117
#   validation accuracy: 			8.51 %
# Epoch 51 of 100 took 11.215s
#   training loss (in-iteration): 	4.176198
#   validation accuracy: 			8.05 %
# Epoch 52 of 100 took 11.151s
#   training loss (in-iteration): 	4.168990
#   validation accuracy: 			8.29 %
# Epoch 53 of 100 took 11.076s
#   training loss (in-iteration): 	4.158998
#   validation accuracy: 			8.46 %
# Epoch 54 of 100 took 10.935s
#   training loss (in-iteration): 	4.153341
#   validation accuracy: 			8.83 %
# Epoch 55 of 100 took 11.079s
#   training loss (in-iteration): 	4.140567
#   validation accuracy: 			8.73 %
# Epoch 56 of 100 took 11.189s
#   training loss (in-iteration): 	4.134055
#   validation accuracy: 			8.65 %
# Epoch 57 of 100 took 11.180s
#   training loss (in-iteration): 	4.126613
#   validation accuracy: 			8.58 %
# Epoch 58 of 100 took 11.093s
#   training loss (in-iteration): 	4.117140
#   validation accuracy: 			7.88 %
# Epoch 59 of 100 took 10.949s
#   training loss (in-iteration): 	4.109558
#   validation accuracy: 			8.48 %
# Epoch 60 of 100 took 11.084s
#   training loss (in-iteration): 	4.100396
#   validation accuracy: 			7.91 %
# Epoch 61 of 100 took 11.241s
#   training loss (in-iteration): 	4.092202
#   validation accuracy: 			8.51 %
# Epoch 62 of 100 took 11.232s
#   training loss (in-iteration): 	4.081869
#   validation accuracy: 			8.39 %
# Epoch 63 of 100 took 11.059s
#   training loss (in-iteration): 	4.077273
#   validation accuracy: 			7.96 %
# Epoch 64 of 100 took 10.914s
#   training loss (in-iteration): 	4.064729
#   validation accuracy: 			8.64 %
# Epoch 65 of 100 took 11.057s
#   training loss (in-iteration): 	4.060884
#   validation accuracy: 			8.03 %
# Epoch 66 of 100 took 11.211s
#   training loss (in-iteration): 	4.051210
#   validation accuracy: 			8.56 %
# Epoch 67 of 100 took 11.227s
#   training loss (in-iteration): 	4.039351
#   validation accuracy: 			8.51 %
# Epoch 68 of 100 took 11.063s
#   training loss (in-iteration): 	4.034969
#   validation accuracy: 			8.73 %
# Epoch 69 of 100 took 11.036s
#   training loss (in-iteration): 	4.025436
#   validation accuracy: 			8.06 %
# Epoch 70 of 100 took 11.119s
#   training loss (in-iteration): 	4.019747
#   validation accuracy: 			7.54 %
# Epoch 71 of 100 took 11.253s
#   training loss (in-iteration): 	4.009624
#   validation accuracy: 			8.43 %
# Epoch 72 of 100 took 11.160s
#   training loss (in-iteration): 	3.999408
#   validation accuracy: 			8.56 %
# Epoch 73 of 100 took 10.956s
#   training loss (in-iteration): 	3.994044
#   validation accuracy: 			6.99 %
# Epoch 74 of 100 took 11.030s
#   training loss (in-iteration): 	3.982988
#   validation accuracy: 			8.29 %
# Epoch 75 of 100 took 11.153s
#   training loss (in-iteration): 	3.977144
#   validation accuracy: 			7.77 %
# Epoch 76 of 100 took 11.188s
#   training loss (in-iteration): 	3.964639
#   validation accuracy: 			7.35 %
# Epoch 77 of 100 took 11.185s
#   training loss (in-iteration): 	3.961798
#   validation accuracy: 			8.30 %
# Epoch 78 of 100 took 10.914s
#   training loss (in-iteration): 	3.953477
#   validation accuracy: 			7.25 %
# Epoch 79 of 100 took 11.043s
#   training loss (in-iteration): 	3.940324
#   validation accuracy: 			7.54 %
# Epoch 80 of 100 took 11.195s
#   training loss (in-iteration): 	3.933413
#   validation accuracy: 			7.91 %
# Epoch 81 of 100 took 11.194s
#   training loss (in-iteration): 	3.929005
#   validation accuracy: 			7.87 %
# Epoch 82 of 100 took 11.221s
#   training loss (in-iteration): 	3.921084
#   validation accuracy: 			7.05 %
# Epoch 83 of 100 took 10.932s
#   training loss (in-iteration): 	3.908722
#   validation accuracy: 			8.16 %
# Epoch 84 of 100 took 10.993s
#   training loss (in-iteration): 	3.903925
#   validation accuracy: 			6.29 %
# Epoch 85 of 100 took 11.074s
#   training loss (in-iteration): 	3.890391
#   validation accuracy: 			7.54 %
# Epoch 86 of 100 took 11.161s
#   training loss (in-iteration): 	3.884104
#   validation accuracy: 			7.51 %
# Epoch 87 of 100 took 11.213s
#   training loss (in-iteration): 	3.876946
#   validation accuracy: 			6.49 %
# Epoch 88 of 100 took 10.954s
#   training loss (in-iteration): 	3.868692
#   validation accuracy: 			7.98 %
# Epoch 89 of 100 took 11.008s
#   training loss (in-iteration): 	3.858957
#   validation accuracy: 			6.76 %
# Epoch 90 of 100 took 11.148s
#   training loss (in-iteration): 	3.859019
#   validation accuracy: 			7.55 %
# Epoch 91 of 100 took 11.248s
#   training loss (in-iteration): 	3.846305
#   validation accuracy: 			7.61 %
# Epoch 92 of 100 took 11.173s
#   training loss (in-iteration): 	3.835976
#   validation accuracy: 			7.93 %
# Epoch 93 of 100 took 11.002s
#   training loss (in-iteration): 	3.825245
#   validation accuracy: 			6.84 %
# Epoch 94 of 100 took 11.017s
#   training loss (in-iteration): 	3.814439
#   validation accuracy: 			6.25 %
# Epoch 95 of 100 took 11.157s
#   training loss (in-iteration): 	3.813349
#   validation accuracy: 			6.55 %
# Epoch 96 of 100 took 11.207s
#   training loss (in-iteration): 	3.804220
#   validation accuracy: 			7.65 %
# Epoch 97 of 100 took 11.136s
#   training loss (in-iteration): 	3.798707
#   validation accuracy: 			7.65 %
# Epoch 98 of 100 took 11.043s
#   training loss (in-iteration): 	3.787526
#   validation accuracy: 			6.91 %
# Epoch 99 of 100 took 11.010s
#   training loss (in-iteration): 	3.785346
#   validation accuracy: 			7.61 %
# Epoch 100 of 100 took 11.121s
#   training loss (in-iteration): 	3.775430
#   validation accuracy: 			6.52 %

# %% [markdown]
# Don't wait for full 100 epochs. You can interrupt training after 5-20 epochs once validation accuracy stops going up.
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ### Final test

# %%
print (6)
# Out:
# 6

# %%
model.train(False) # disable dropout / use averages for batch_norm
test_batch_acc = []
for X_batch, y_batch in iterate_minibatches(X_test, y_test, 500):
    logits = model(Variable(torch.FloatTensor(X_batch)).cuda())
    y_pred = logits.cpu().max(1)[1].data.numpy()
    test_batch_acc.append(np.mean(y_batch == y_pred))

test_accuracy = np.mean(test_batch_acc)
    
print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_accuracy * 100))

if test_accuracy * 100 > 95:
    print("Double-check, than consider applying for NIPS'17. SRSly.")
elif test_accuracy * 100 > 90:
    print("U'r freakin' amazin'!")
elif test_accuracy * 100 > 80:
    print("Achievement unlocked: 110lvl Warlock!")
elif test_accuracy * 100 > 70:
    print("Achievement unlocked: 80lvl Warlock!")
elif test_accuracy * 100 > 60:
    print("Achievement unlocked: 70lvl Warlock!")
elif test_accuracy * 100 > 50:
    print("Achievement unlocked: 60lvl Warlock!")
else:
    print("We need more magic! Follow instructons below")
# Out:
# Final results:
#   test accuracy:		6.76 %
# We need more magic! Follow instructons below

# %% [markdown]
# ## Task I: small convolution net
# ### First step
#
# Let's create a mini-convolutional network with roughly such architecture:
# * Input layer
# * 3x3 convolution with 10 filters and _ReLU_ activation
# * 2x2 pooling (or set previous convolution stride to 3)
# * Flatten
# * Dense layer with 100 neurons and _ReLU_ activation
# * 10% dropout
# * Output dense layer.
#
#
# __Convolutional layers__ in torch are just like all other layers, but with a specific set of parameters:
#
# __`...`__
#
# __`model.add_module('conv1', nn.Conv2d(in_channels=3, out_channels=10, kernel_size=3)) # convolution`__
#
# __`model.add_module('pool1', nn.MaxPool2d(2)) # max pooling 2x2`__
#
# __`...`__
#
#
# Once you're done (and compute_loss no longer raises errors), train it with __Adam__ optimizer with default params (feel free to modify the code above).
#
# If everything is right, you should get at least __50%__ validation accuracy.

# %%
model = nn.Sequential()

# reshape from "images" to flat vectors
#model.add_module('flatten', Flatten())

# dense "head"
model.add_module('conv1', nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, stride=1, padding=2)) # convolution
model.add_module('conv_relu', nn.LeakyReLU(0.1)) # convolution
model.add_module('batch norm1', nn.BatchNorm2d(64))
model.add_module('pool1', nn.MaxPool2d(kernel_size=2, stride=2)) # max pooling 2x2

model.add_module('conv2', nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=2)) # convolution
model.add_module('conv_relu2', nn.LeakyReLU(0.1)) # convolution
model.add_module('batch norm1', nn.BatchNorm2d(64))
model.add_module('pool2', nn.MaxPool2d(kernel_size=2, stride=2)) # max pooling 2x2

#model.add_module('conv3', nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=2)) # convolution
#model.add_module('conv_relu3', nn.LeakyReLU(0.1)) # convolution
#model.add_module('pool3', nn.MaxPool2d(kernel_size=2, stride=2)) # max pooling 2x2

#model.add_module('conv4', nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=2)) # convolution
#model.add_module('conv_relu4', nn.LeakyReLU(0.1)) # convolution
#model.add_module('pool4', nn.MaxPool2d(kernel_size=2, stride=2)) # max pooling 2x2

model.add_module('flatten', Flatten())
model.add_module('dense1', nn.Linear(18496, 1024))
model.add_module('dropout', nn.Dropout(0.1)) 
model.add_module('dense1_relu', nn.ReLU())
model.add_module('dense1_logits', nn.Linear(1024, 200)) # logits for 200 classes

# %%
opt = torch.optim.Adam(model.parameters(), lr=0.05)

train_loss = []
val_accuracy = []

# %%
from torchsummary import summary

summary(model.cuda(), (3, 64, 64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 66, 66]           1,792
#          LeakyReLU-2           [-1, 64, 66, 66]               0
#        BatchNorm2d-3           [-1, 64, 66, 66]             128
#          MaxPool2d-4           [-1, 64, 33, 33]               0
#             Conv2d-5           [-1, 64, 35, 35]          36,928
#          LeakyReLU-6           [-1, 64, 35, 35]               0
#          MaxPool2d-7           [-1, 64, 17, 17]               0
#            Flatten-8                [-1, 18496]               0
#             Linear-9                 [-1, 1024]      18,940,928
#           Dropout-10                 [-1, 1024]               0
#              ReLU-11                 [-1, 1024]               0
#            Linear-12                  [-1, 200]         205,000
# ================================================================
# Total params: 19,184,776
# Trainable params: 19,184,776
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 8.42
# Params size (MB): 73.18
# Estimated Total Size (MB): 81.65
# ----------------------------------------------------------------

# %% [markdown]
# ## retrain it ##

# %%
import time
num_epochs = 100 # total amount of full passes over training data
batch_size = 16  # number of samples processed in one SGD iteration


for epoch in range(num_epochs):
    print (num_epochs)
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for X_batch, y_batch in iterate_minibatches(X_train, y_train, batch_size):
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.data.cpu().numpy())
    print (num_epochs)    
    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in iterate_minibatches(X_val, y_val, batch_size):
        logits = model(Variable(torch.FloatTensor(X_batch)).cuda())
        y_pred = logits.cpu().max(1)[1].data.numpy()
        val_accuracy.append(np.mean(y_batch == y_pred))

    print (num_epochs)
    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(X_train) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(X_val) // batch_size :]) * 100))
# Out:
# 100
# 100
# 100
# Epoch 1 of 100 took 320.767s
#   training loss (in-iteration): 	58.916637
#   validation accuracy: 			0.51 %
# 100
# 100
# 100
# Epoch 2 of 100 took 320.684s
#   training loss (in-iteration): 	5.342665
#   validation accuracy: 			0.52 %
# 100
# 100
# 100
# Epoch 3 of 100 took 320.842s
#   training loss (in-iteration): 	5.342202
#   validation accuracy: 			0.47 %
# 100

# %% [markdown]
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# __Hint:__ If you don't want to compute shapes by hand, just plug in any shape (e.g. 1 unit) and run compute_loss. You will see something like this:
#
# __`RuntimeError: size mismatch, m1: [5 x 1960], m2: [1 x 64] at /some/long/path/to/torch/operation`__
#
# See the __1960__ there? That's your actual input shape.
#
# ## Task 2: adding normalization
#
# * Add batch norm (with default params) between convolution and ReLU
#   * nn.BatchNorm*d (1d for dense, 2d for conv)
#   * usually better to put them after linear/conv but before nonlinearity
# * Re-train the network with the same optimizer, it should get at least 60% validation accuracy at peak.

# %% [markdown]
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
# ## Task 3: Data Augmentation
#
# There's a powerful torch tool for image preprocessing useful to do data preprocessing and augmentation.
#
# Here's how it works: we define a pipeline that
# * makes random crops of data (augmentation)
# * randomly flips image horizontally (augmentation)
# * then normalizes it (preprocessing)

# %%
from torchvision import transforms
means = np.array((0.4914, 0.4822, 0.4465))
stds = np.array((0.2023, 0.1994, 0.2010))

transform_augment = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomRotation([-30, 30]),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(means, stds),
])

# %%
from torchvision.datasets import CIFAR10
train_loader = CIFAR10("./cifar_data/", train=True, transform=transform_augment)

train_batch_gen = torch.utils.data.DataLoader(train_loader, 
                                              batch_size=32,
                                              shuffle=True,
                                              num_workers=1)

# %%
for (x_batch, y_batch) in train_batch_gen:
    
    print('X:', type(x_batch), x_batch.shape)
    print('y:', type(y_batch), y_batch.shape)
    
    for i, img in enumerate(x_batch.numpy()[:8]):
        plt.subplot(2, 4, i+1)
        plt.imshow(img.transpose([1,2,0]) * stds + means )
        
    
    raise NotImplementedError("Plese use this code in your training loop")
    # TODO use this in your training loop

# %% [markdown]
# When testing, we don't need random crops, just normalize with same statistics.

# %%
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(means, stds),
])

test_loader = <YOUR CODE>

# %% [markdown]
# ## The Quest For A Better Network
#
# See `practical_dl/homework02` for a full-scale assignment.
