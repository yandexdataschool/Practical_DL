# %% [markdown]
# # Deep learning for computer vision
#
#
# This notebook will teach you to build and train convolutional networks for image recognition. Brace yourselves.

# %% [markdown]
# # Tiny ImageNet dataset
# This week, we shall focus on the image recognition problem on Tiny Image Net dataset
# * 100k images of shape 3x64x64
# * 200 different classes: snakes, spaiders, cats, trucks, grasshopper, gull, etc.

# %%
import torchvision
import torch
from torchvision import transforms

# %%
from tiny_img import download_tinyImg200
data_path = '.'
download_tinyImg200(data_path)
# Out:
# ./tiny-imagenet-200.zip

# %%
dataset = torchvision.datasets.ImageFolder('tiny-imagenet-200/train', transform=transforms.ToTensor())
test_dataset = torchvision.datasets.ImageFolder('tiny-imagenet-200/val', transform=transforms.ToTensor())
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [80000, 20000])
test_dataset, val_dataset = torch.utils.data.random_split(val_dataset, [10000, 10000])

# %%
batch_size = 50
train_batch_gen = torch.utils.data.DataLoader(train_dataset, 
                                              batch_size=batch_size,
                                              shuffle=True,
                                              num_workers=1)

# %%
val_batch_gen = torch.utils.data.DataLoader(val_dataset, 
                                              batch_size=batch_size,
                                              shuffle=True,
                                              num_workers=1)

# %% [markdown]
# ## Example of equals image classes ##

# %% [markdown]
# <tr>
#     <td> <img src="tinyim3.png" alt="Drawing" style="width:90%"/> </td>
#     <td> <img src="tinyim2.png" alt="Drawing" style="width:90%"/> </td>
# </tr>

# %% [markdown]
# <tr>
#     <td> <img src="tinyim3.png" alt="Drawing" style="width:90%"/> </td>
#     <td> <img src="tiniim.png" alt="Drawing" style="width:90%"/> </td>
# </tr>

# %% [markdown]
# # Building a network
#
# Simple neural networks with layers applied on top of one another can be implemented as `torch.nn.Sequential` - just add a list of pre-built modules and let it train.

# %%
import torch, torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

# a special module that converts [batch, channel, w, h] to [batch, units]
class Flatten(nn.Module):
    def forward(self, input):
        return input.view(input.size(0), -1)

# %% [markdown]
# Let's start with a dense network for our baseline:

# %%
model = nn.Sequential()

# reshape from "images" to flat vectors
model.add_module('flatten', Flatten())

# dense "head"
model.add_module('dense1', nn.Linear(3 * 64 * 64, 1064))
model.add_module('dense2', nn.Linear(1064, 512))
model.add_module('dropout0', nn.Dropout(0.05)) 
model.add_module('dense3', nn.Linear(512, 256))
model.add_module('dropout1', nn.Dropout(0.05))
model.add_module('dense4', nn.Linear(256, 64))
model.add_module('dropout2', nn.Dropout(0.05))
model.add_module('dense1_relu', nn.ReLU())
model.add_module('dense2_logits', nn.Linear(64, 200)) # logits for 200 classes

# %% [markdown]
# As in our basic tutorial, we train our model with negative log-likelihood aka crossentropy.

# %%
def compute_loss(X_batch, y_batch):
    X_batch = Variable(torch.FloatTensor(X_batch)).cuda()
    y_batch = Variable(torch.LongTensor(y_batch)).cuda()
    logits = model.cuda()(X_batch)
    return F.cross_entropy(logits, y_batch).mean()

# %% [markdown]
# ### Training on minibatches
# * We got 100k images, that's way too many for a full-batch SGD. Let's train on minibatches instead
# * Below is a function that splits the training sample into minibatches

# %%
opt = torch.optim.SGD(model.parameters(), lr=0.01)

train_loss = []
val_accuracy = []

# %%
import numpy as np

opt = torch.optim.SGD(model.parameters(), lr=0.01)

train_loss = []
val_accuracy = []

num_epochs = 50 # total amount of full passes over training data

import time

for epoch in range(num_epochs):
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for (X_batch, y_batch) in train_batch_gen:
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.cpu().data.numpy())
    
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in val_batch_gen:
        logits = model(Variable(torch.FloatTensor(X_batch)).cuda())
        y_pred = logits.max(1)[1].data
        val_accuracy.append(np.mean( (y_batch.cpu() == y_pred.cpu()).numpy() ))

    
    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(train_dataset) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(val_dataset) // batch_size :]) * 100))

# %% [markdown]
# Don't wait for full 100 epochs. You can interrupt training after 5-20 epochs once validation accuracy stops going up.
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ### Final test

# %%
model.train(False) # disable dropout / use averages for batch_norm
test_batch_acc = []
for X_batch, y_batch in val_batch_test:
    logits = model(Variable(torch.FloatTensor(X_batch)).cuda())
    y_pred = logits.max(1)[1].data
    test_batch_acc.append(np.mean( (y_batch.cpu() == y_pred.cpu()).numpy() ))


test_accuracy = np.mean(test_batch_acc)
    
print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_accuracy * 100))

if test_accuracy * 100 > 70:
    print("U'r freakin' amazin'!")
elif test_accuracy * 100 > 50:
    print("Achievement unlocked: 110lvl Warlock!")
elif test_accuracy * 100 > 40:
    print("Achievement unlocked: 80lvl Warlock!")
elif test_accuracy * 100 > 30:
    print("Achievement unlocked: 70lvl Warlock!")
elif test_accuracy * 100 > 20:
    print("Achievement unlocked: 60lvl Warlock!")
else:
    print("We need more magic! Follow instructons below")

# %% [markdown]
# ## Task I: small convolution net
# ### First step
#
# Let's create a mini-convolutional network with roughly such architecture:
# * Input layer
# * 3x3 convolution with 128 filters and _ReLU_ activation
# * 2x2 pooling (or set previous convolution stride to 3)
# * Flatten
# * Dense layer with 1024 neurons and _ReLU_ activation
# * 30% dropout
# * Output dense layer.
#
#
# __Convolutional layers__ in torch are just like all other layers, but with a specific set of parameters:
#
# __`...`__
#
# __`model.add_module('conv1', nn.Conv2d(in_channels=3, out_channels=128, kernel_size=3)) # convolution`__
#
# __`model.add_module('pool1', nn.MaxPool2d(2)) # max pooling 2x2`__
#
# __`...`__
#
#
# Once you're done (and compute_loss no longer raises errors), train it with __Adam__ optimizer with default params (feel free to modify the code above).
#
# If everything is right, you should get at least __16%__ validation accuracy.
#
# __HACK_OF_THE_DAY__ :the number of channels must be in the order of the number of class_labels

# %%
model = nn.Sequential()

#decribe convnet here

model.add_module('dense1_logits', nn.Linear(1024, 200)) # logits for 200 classes

# %%
opt = torch.optim.SGD(model.parameters(), lr=0.01)

train_loss = []
val_accuracy = []

# %%
from torchsummary import summary

summary(model.cuda(), (3, 64, 64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 100, 32, 32]           4,900
#               ReLU-2          [-1, 100, 32, 32]               0
#          MaxPool2d-3          [-1, 100, 16, 16]               0
#             Conv2d-4          [-1, 100, 13, 13]         160,100
#               ReLU-5          [-1, 100, 13, 13]               0
#          MaxPool2d-6            [-1, 100, 6, 6]               0
#            Flatten-7                 [-1, 3600]               0
#             Linear-8                 [-1, 1024]       3,687,424
#            Dropout-9                 [-1, 1024]               0
#              ReLU-10                 [-1, 1024]               0
#            Linear-11                  [-1, 200]         205,000
# ================================================================
# Total params: 4,057,424
# Trainable params: 4,057,424
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 2.10
# Params size (MB): 15.48
# Estimated Total Size (MB): 17.62
# ----------------------------------------------------------------

# %% [markdown]
# ## retrain it ##

# %%
import time
num_epochs = 100 # total amount of full passes over training data
batch_size = 50  # number of samples processed in one SGD iteration


for epoch in range(num_epochs):
    print (num_epochs)
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for (X_batch, y_batch) in train_batch_gen:
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.data.cpu().numpy())
    print (num_epochs)    
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in val_batch_gen:
        logits = model(Variable(torch.FloatTensor(X_batch)).cuda())
        y_pred = logits.max(1)[1].data
        val_accuracy.append(np.mean( (y_batch.cpu() == y_pred.cpu()).numpy() ))

    print (num_epochs)
    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(train_dataset) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(val_dataset) // batch_size :]) * 100))
# Out:
# 100
# 100
# 100
# Epoch 1 of 100 took 105.702s
#   training loss (in-iteration): 	5.149884
#   validation accuracy: 			1.99 %
# 100
# Process Process-22:
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/conda/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-bb56f31d479d> in <module>()
#      11     for (X_batch, y_batch) in train_batch_gen:
#      12         # train on batch
# ---> 13         loss = compute_loss(X_batch, y_batch)
#      14         loss.backward()
#      15         opt.step()
#
# <ipython-input-7-12220ad54a78> in compute_loss(X_batch, y_batch)
#       1 def compute_loss(X_batch, y_batch):
#       2     X_batch = Variable(torch.FloatTensor(X_batch)).cuda()
# ----> 3     y_batch = Variable(torch.LongTensor(y_batch)).cuda()
#       4     logits = model.cuda()(X_batch)
#       5     return F.cross_entropy(logits, y_batch).mean()
#
# KeyboardInterrupt:
#   File "/opt/conda/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sayankotor/.local/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 106, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/sayankotor/.local/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 106, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/sayankotor/.local/lib/python3.6/site-packages/torch/utils/data/dataset.py", line 103, in __getitem__
#     return self.dataset[self.indices[idx]]
#   File "/opt/conda/anaconda3/lib/python3.6/site-packages/torchvision/datasets/folder.py", line 65, in __getitem__
#     img = self.loader(path)
#   File "/opt/conda/anaconda3/lib/python3.6/site-packages/torchvision/datasets/folder.py", line 42, in default_loader
#     return Image.open(path).convert('RGB')
#   File "/opt/conda/anaconda3/lib/python3.6/site-packages/PIL/Image.py", line 2486, in open
#     prefix = fp.read(16)

# %% [markdown]
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# __Hint:__ If you don't want to compute shapes by hand, just plug in any shape (e.g. 1 unit) and run compute_loss. You will see something like this:
#
# __`RuntimeError: size mismatch, m1: [5 x 1960], m2: [1 x 64] at /some/long/path/to/torch/operation`__
#
# See the __1960__ there? That's your actual input shape.
#
# ## Task 2: adding normalization
#
# * Add batch norm (with default params) between convolution and ReLU
#   * nn.BatchNorm*d (1d for dense, 2d for conv)
#   * usually better to put them after linear/conv but before nonlinearity
# * Re-train the network with the same optimizer, it should get at least 20% validation accuracy at peak.
#
# To know more about **batch_norm** and **data covariate shift**
#
# https://towardsdatascience.com/batch-normalization-in-neural-networks-1ac91516821c
#
# https://www.youtube.com/watch?v=nUUqwaxLnWs

# %%
model = nn.Sequential()

#decribe conv net with batchnorm here
model.add_module('dense1_logits', nn.Linear(1024, 200)) # logits for 200 classes

# %%
opt = torch.optim.SGD(model.parameters(), lr=0.01)

train_loss = []
val_accuracy = []

# %%
import time
num_epochs = 100 # total amount of full passes over training data
batch_size = 50  # number of samples processed in one SGD iteration


for epoch in range(num_epochs):
    print (num_epochs)
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for (X_batch, y_batch) in train_batch_gen:
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.data.cpu().numpy())
    print (num_epochs)    
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in val_batch_gen:
        logits = model(Variable(torch.FloatTensor(X_batch)).cuda())
        y_pred = logits.max(1)[1].data
        val_accuracy.append(np.mean( (y_batch.cpu() == y_pred.cpu()).numpy() ))

    print (num_epochs)
    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(train_dataset) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(val_dataset) // batch_size :]) * 100))
# Out:
# 100
# 100
# 100
# Epoch 1 of 100 took 157.897s
#   training loss (in-iteration): 	4.253258
#   validation accuracy: 			15.70 %
# 100
# 100
# 100
# Epoch 2 of 100 took 157.694s
#   training loss (in-iteration): 	3.923770
#   validation accuracy: 			16.85 %
# 100
# 100
# 100
# Epoch 3 of 100 took 158.053s
#   training loss (in-iteration): 	3.695406
#   validation accuracy: 			19.79 %
# 100
# 100
# 100
# Epoch 4 of 100 took 157.778s
#   training loss (in-iteration): 	3.522153
#   validation accuracy: 			19.62 %
# 100
# 100
# 100
# Epoch 5 of 100 took 158.123s
#   training loss (in-iteration): 	3.365790
#   validation accuracy: 			20.59 %
# 100
# 100
# 100
# Epoch 6 of 100 took 157.330s
#   training loss (in-iteration): 	3.226531
#   validation accuracy: 			21.09 %
# 100

# %% [markdown]
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
# ## Task 3: Data Augmentation
#
# ** Augmenti - A spell used to produce water from a wand (Harry Potter Wiki) **
#
# <img src="HagridsHut_PM_B6C28_Hagrid_sHutFireHarryFang.jpg" style="width:80%">
#
# There's a powerful torch tool for image preprocessing useful to do data preprocessing and augmentation.
#
# Here's how it works: we define a pipeline that
# * makes random crops of data (augmentation)
# * randomly flips image horizontally (augmentation)
# * then normalizes it (preprocessing)

# %% [markdown]
# When testing, we don't need random crops, just normalize with same statistics.

# %%
import torchvision
from torchvision import transforms
means = np.array((0.4914, 0.4822, 0.4465))
stds = np.array((0.2023, 0.1994, 0.2010))

transform_augment = transforms.Compose([
    # decribe transformation here
])

# %%
dataset = torchvision.datasets.ImageFolder('tiny-imagenet-200/train', transform=transform_augment)

# %%
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [90000, 10000])

# %%
train_batch_gen = torch.utils.data.DataLoader(train_dataset, 
                                              batch_size=batch_size,
                                              shuffle=True,
                                              num_workers=1)

# %%
val_batch_gen = torch.utils.data.DataLoader(val_dataset, 
                                              batch_size=batch_size,
                                              shuffle=True,
                                              num_workers=1)

# %%
import time
num_epochs = 100 # total amount of full passes over training data
batch_size = 50  # number of samples processed in one SGD iteration


for epoch in range(num_epochs):
    print (num_epochs)
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for (X_batch, y_batch) in train_batch_gen:
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.data.cpu().numpy())
    print (num_epochs)    
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in val_batch_gen:
        logits = model(Variable(torch.FloatTensor(X_batch)).cuda())
        y_pred = logits.max(1)[1].data
        val_accuracy.append(np.mean( (y_batch.cpu() == y_pred.cpu()).numpy() ))

    print (num_epochs)
    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(train_dataset) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(val_dataset) // batch_size :]) * 100))
# Out:
# 100
# 100
# 100
# Epoch 1 of 100 took 261.549s
#   training loss (in-iteration): 	3.532589
#   validation accuracy: 			25.09 %
# 100
# 100
# 100
# Epoch 2 of 100 took 261.145s
#   training loss (in-iteration): 	3.285550
#   validation accuracy: 			29.39 %
# 100
# 100
# 100
# Epoch 3 of 100 took 254.665s
#   training loss (in-iteration): 	3.111224
#   validation accuracy: 			31.01 %
# 100
# 100
# 100
# Epoch 4 of 100 took 193.659s
#   training loss (in-iteration): 	2.972642
#   validation accuracy: 			32.73 %
# 100
# 100
# 100
# Epoch 5 of 100 took 193.250s
#   training loss (in-iteration): 	2.853618
#   validation accuracy: 			34.45 %
# 100
# 100
# 100
# Epoch 6 of 100 took 193.386s
#   training loss (in-iteration): 	2.753282
#   validation accuracy: 			35.52 %
# 100
# 100
# 100
# Epoch 7 of 100 took 193.731s
#   training loss (in-iteration): 	2.658695
#   validation accuracy: 			36.08 %
# 100
# 100
# 100
# Epoch 8 of 100 took 193.092s
#   training loss (in-iteration): 	2.576960
#   validation accuracy: 			37.05 %
# 100
# 100
# 100
# Epoch 9 of 100 took 193.452s
#   training loss (in-iteration): 	2.499869
#   validation accuracy: 			37.42 %
# 100
# 100
# 100
# Epoch 10 of 100 took 192.805s
#   training loss (in-iteration): 	2.427078
#   validation accuracy: 			37.55 %
# 100
# 100
# 100
# Epoch 11 of 100 took 194.165s
#   training loss (in-iteration): 	2.372354
#   validation accuracy: 			38.43 %
# 100
# 100
# 100
# Epoch 12 of 100 took 193.155s
#   training loss (in-iteration): 	2.298627
#   validation accuracy: 			39.00 %
# 100
# 100
# 100
# Epoch 13 of 100 took 193.148s
#   training loss (in-iteration): 	2.248116
#   validation accuracy: 			38.75 %
# 100
# 100
# 100
# Epoch 14 of 100 took 193.521s
#   training loss (in-iteration): 	2.196328
#   validation accuracy: 			38.78 %
# 100
# 100
# 100
# Epoch 15 of 100 took 193.570s
#   training loss (in-iteration): 	2.144087
#   validation accuracy: 			39.60 %
# 100
# 100
# 100
# Epoch 16 of 100 took 193.164s
#   training loss (in-iteration): 	2.092249
#   validation accuracy: 			39.75 %
# 100
# 100
# 100
# Epoch 17 of 100 took 193.679s
#   training loss (in-iteration): 	2.041836
#   validation accuracy: 			39.59 %
# 100
# 100
# 100
# Epoch 18 of 100 took 192.807s
#   training loss (in-iteration): 	1.998702
#   validation accuracy: 			39.84 %
# 100
# 100
# 100
# Epoch 19 of 100 took 192.894s
#   training loss (in-iteration): 	1.953996
#   validation accuracy: 			39.75 %
# 100
# 100
# 100
# Epoch 20 of 100 took 193.676s
#   training loss (in-iteration): 	1.913653
#   validation accuracy: 			40.72 %
# 100
# 100
# 100
# Epoch 21 of 100 took 193.344s
#   training loss (in-iteration): 	1.873472
#   validation accuracy: 			39.59 %
# 100
# 100
# 100
# Epoch 22 of 100 took 193.260s
#   training loss (in-iteration): 	1.837914
#   validation accuracy: 			40.17 %
# 100
# 100
# 100
# Epoch 23 of 100 took 193.292s
#   training loss (in-iteration): 	1.803179
#   validation accuracy: 			39.69 %
# 100
# 100
# 100
# Epoch 24 of 100 took 193.788s
#   training loss (in-iteration): 	1.773098
#   validation accuracy: 			39.95 %
# 100
# 100
# 100
# Epoch 25 of 100 took 193.694s
#   training loss (in-iteration): 	1.737546
#   validation accuracy: 			40.43 %
# 100
# 100
# 100
# Epoch 26 of 100 took 192.725s
#   training loss (in-iteration): 	1.704152
#   validation accuracy: 			40.21 %
# 100
# 100
# 100
# Epoch 27 of 100 took 193.693s
#   training loss (in-iteration): 	1.670091
#   validation accuracy: 			40.26 %
# 100
# 100
# 100
# Epoch 28 of 100 took 192.714s
#   training loss (in-iteration): 	1.634897
#   validation accuracy: 			40.20 %
# 100
# 100
# 100
# Epoch 29 of 100 took 193.656s
#   training loss (in-iteration): 	1.623998
#   validation accuracy: 			40.40 %
# 100
# 100
# 100
# Epoch 30 of 100 took 194.201s
#   training loss (in-iteration): 	1.590612
#   validation accuracy: 			40.31 %
# 100
# 100
# 100
# Epoch 31 of 100 took 193.476s
#   training loss (in-iteration): 	1.561345
#   validation accuracy: 			40.19 %
# 100
# 100
# 100
# Epoch 32 of 100 took 193.130s
#   training loss (in-iteration): 	1.537698
#   validation accuracy: 			40.35 %
# 100
# 100
# 100
# Epoch 33 of 100 took 189.077s
#   training loss (in-iteration): 	1.513917
#   validation accuracy: 			40.58 %
# 100
# 100
# 100
# Epoch 34 of 100 took 131.530s
#   training loss (in-iteration): 	1.491515
#   validation accuracy: 			39.74 %
# 100
# 100
# 100
# Epoch 35 of 100 took 132.362s
#   training loss (in-iteration): 	1.468504
#   validation accuracy: 			39.59 %
# 100
# 100
# 100
# Epoch 36 of 100 took 131.653s
#   training loss (in-iteration): 	1.449047
#   validation accuracy: 			39.71 %
# 100
# 100
# 100
# Epoch 37 of 100 took 197.040s
#   training loss (in-iteration): 	1.426154
#   validation accuracy: 			39.83 %
# 100
# 100
# 100
# Epoch 38 of 100 took 201.107s
#   training loss (in-iteration): 	1.402315
#   validation accuracy: 			39.65 %
# 100
# 100
# 100
# Epoch 39 of 100 took 204.257s
#   training loss (in-iteration): 	1.384826
#   validation accuracy: 			40.02 %
# 100
# 100
# 100
# Epoch 40 of 100 took 203.783s
#   training loss (in-iteration): 	1.367973
#   validation accuracy: 			39.96 %
# 100
# 100
# 100
# Epoch 41 of 100 took 176.678s
#   training loss (in-iteration): 	1.347716
#   validation accuracy: 			40.34 %
# 100
# 100
# 100
# Epoch 42 of 100 took 213.536s
#   training loss (in-iteration): 	1.331246
#   validation accuracy: 			40.16 %
# 100
# 100
# 100
# Epoch 43 of 100 took 212.906s
#   training loss (in-iteration): 	1.319067
#   validation accuracy: 			40.27 %
# 100
# 100
# 100
# Epoch 44 of 100 took 213.160s
#   training loss (in-iteration): 	1.295712
#   validation accuracy: 			39.89 %
# 100
# 100
# 100
# Epoch 45 of 100 took 212.835s
#   training loss (in-iteration): 	1.281570
#   validation accuracy: 			39.89 %
# 100
# 100
# 100
# Epoch 46 of 100 took 213.093s
#   training loss (in-iteration): 	1.267456
#   validation accuracy: 			39.94 %
# 100
# 100
# 100
# Epoch 47 of 100 took 213.384s
#   training loss (in-iteration): 	1.257738
#   validation accuracy: 			40.02 %
# 100
# 100
# 100
# Epoch 48 of 100 took 213.394s
#   training loss (in-iteration): 	1.240367
#   validation accuracy: 			39.84 %
# 100
# 100
# 100
# Epoch 49 of 100 took 212.652s
#   training loss (in-iteration): 	1.224051
#   validation accuracy: 			39.87 %
# 100
# 100
# 100
# Epoch 50 of 100 took 212.424s
#   training loss (in-iteration): 	1.219095
#   validation accuracy: 			40.06 %
# 100
# 100
# 100
# Epoch 51 of 100 took 213.962s
#   training loss (in-iteration): 	1.207302
#   validation accuracy: 			39.88 %
# 100
# 100
# 100
# Epoch 52 of 100 took 213.113s
#   training loss (in-iteration): 	1.176036
#   validation accuracy: 			39.65 %
# 100
# 100
# 100
# Epoch 53 of 100 took 213.785s
#   training loss (in-iteration): 	1.174661
#   validation accuracy: 			39.37 %
# 100
# 100
# 100
# Epoch 54 of 100 took 211.995s
#   training loss (in-iteration): 	1.162088
#   validation accuracy: 			39.71 %
# 100
# 100
# 100
# Epoch 55 of 100 took 212.590s
#   training loss (in-iteration): 	1.143279
#   validation accuracy: 			39.96 %
# 100
# 100
# 100
# Epoch 56 of 100 took 213.155s
#   training loss (in-iteration): 	1.144878
#   validation accuracy: 			39.15 %
# 100
# 100
# 100
# Epoch 57 of 100 took 212.444s
#   training loss (in-iteration): 	1.118125
#   validation accuracy: 			39.18 %
# 100
# 100
# 100
# Epoch 58 of 100 took 212.115s
#   training loss (in-iteration): 	1.109155
#   validation accuracy: 			40.08 %
# 100
# 100
# 100
# Epoch 59 of 100 took 212.854s
#   training loss (in-iteration): 	1.100365
#   validation accuracy: 			40.17 %
# 100
# 100
# 100
# Epoch 60 of 100 took 213.302s
#   training loss (in-iteration): 	1.104934
#   validation accuracy: 			39.86 %
# 100
# 100
# 100
# Epoch 61 of 100 took 212.415s
#   training loss (in-iteration): 	1.083245
#   validation accuracy: 			39.90 %
# 100
# 100
# 100
# Epoch 62 of 100 took 213.055s
#   training loss (in-iteration): 	1.070939
#   validation accuracy: 			39.93 %
# 100
# 100
# 100
# Epoch 63 of 100 took 211.690s
#   training loss (in-iteration): 	1.069129
#   validation accuracy: 			39.94 %
# 100
# 100
# 100
# Epoch 64 of 100 took 198.776s
#   training loss (in-iteration): 	1.059205
#   validation accuracy: 			40.20 %
# 100
# 100
# 100
# Epoch 65 of 100 took 213.426s
#   training loss (in-iteration): 	1.047979
#   validation accuracy: 			39.62 %
# 100
# 100
# 100
# Epoch 66 of 100 took 212.749s
#   training loss (in-iteration): 	1.039514
#   validation accuracy: 			39.23 %
# 100
# 100
# 100
# Epoch 67 of 100 took 213.366s
#   training loss (in-iteration): 	1.023715
#   validation accuracy: 			39.35 %
# 100
# 100
# 100
# Epoch 68 of 100 took 213.447s
#   training loss (in-iteration): 	1.025747
#   validation accuracy: 			39.54 %
# 100
# 100
# 100
# Epoch 69 of 100 took 213.922s
#   training loss (in-iteration): 	1.013937
#   validation accuracy: 			39.21 %
# 100
# 100
# 100
# Epoch 70 of 100 took 212.150s
#   training loss (in-iteration): 	1.011352
#   validation accuracy: 			39.66 %
# 100
# 100
# 100
# Epoch 71 of 100 took 213.240s
#   training loss (in-iteration): 	0.998316
#   validation accuracy: 			39.17 %
# 100
# 100
# 100
# Epoch 72 of 100 took 213.368s
#   training loss (in-iteration): 	0.983487
#   validation accuracy: 			39.32 %
# 100
# 100
# 100
# Epoch 73 of 100 took 213.013s
#   training loss (in-iteration): 	0.980354
#   validation accuracy: 			38.88 %
# 100
# 100
# 100
# Epoch 74 of 100 took 213.019s
#   training loss (in-iteration): 	0.975337
#   validation accuracy: 			39.89 %
# 100

# %% [markdown]
# We need for test data __only normalization__, not cropping and rotation

# %%
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(means, stds),
])

test_dataset = <YOUR CODE>
# Out:
#   File "<ipython-input-111-89f8cabd8df5>", line 6
#     test_loader = <YOUR CODE>
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## The Quest For A Better Network
#
# See `practical_dl/homework02` for a full-scale assignment.
