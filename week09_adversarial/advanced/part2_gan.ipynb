# %% [markdown]
# Use adversarial_pytorch.ipynb (it is located in the parent directory) as the second part. Do not forget to generate image samples by your algorithm in order to have data for the third part.
