# %% [markdown]
# DeepLarning Couse HSE 2016 fall: Arseniy Ashuha, you can text me ```ars.ashuha@gmail.com```, ```https://vk.com/ars.ashuha```
#
# Для начала ответьте на несколько вопросов.
#
#
# <h1 align="center"> Checking Questions </h1>
#
# - Чем GoogLeNet отличается от VGG?
#
# <Ответ>
#
# - Чем сверточная сеть отличается от полносвязной?
#
# <Ответ>
#
# - Обязательно ли использовать в сверточной сети полносвзяные слои?
#
# <Ответ>
#
# - Чем рекуррентные сети лучше сверточных?
#
# <Ответ>
#
# - Какие бывают рекуррентные сети?
#
# <Ответ>
#
# - С какими проблемы бывают при обучении рекуррентных сетей?
#
# <Ответ>
#
# - Для каких задач стоит применять сверточные а для каких рекуррентные сети?
#
#
# <Ответ>

# %% [markdown]
# <h1 align="center"> Image Captioning HW</h1>
#
# В этом домашнем задании Вам нужно будет обучить сеть для аннотирования изображений см. семинар.
#
# Вы можете подсматривать в эту статью http://cs.stanford.edu/people/karpathy/cvpr2015.pdf.
#
# **Что нужно сделать?**
# - Что работе лучше подавать признаки картинки только один раз в начале или подавать на каждом шаге?
#
# <Ответ>
#
# - Попробовать разные архитектуры. Какие рекуррентные архитектуры вы попробовали?
#
# <Ответ>
#
# - Какие методы оптимизации лучше работали?
#
# <Ответ>
#
# - Попробуйте разные стратегии выбора следующего слова -- максимум распределения и семплирование.
#
# <Ответ>
#
# - Приведите примеры картинки на которой сеть сделала хорошую аннотацию и абсолютно не адекватную аннотацию?
#
# <Ответ>
#
# **Как должен выглядеть submit?**
# - Нужно сдать ноутбук, с экспериментами и ответами :)
